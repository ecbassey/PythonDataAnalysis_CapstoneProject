# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
fig, ax = plt.subplots()
plt.show()

# %%
df = pd.read_csv("travel_arrival_US.csv")
df.head()
# Out:
#                            Unnamed: 0    1975    1980    1985    1990    1991  \
# 0           TOTAL arriving passengers  12,646  20,262  24,155  42,712  41,236
# 1              United States carriers   6,502  10,031  11,798  21,960  21,639
# 2                    Foreign carriers   6,144  10,231  12,357  20,752  19,597
# 3  Selected countries of embarkationa     NaN     NaN     NaN     NaN     NaN
# 4                              Canada       N       N       N   6,733   6,144
#
#      1992    1993    1994    1995  ...     2016     2017     2018     2019  \
# 0  45,084  47,353  49,558  52,991  ...  108,285  113,959  119,957  122,563
# 1  23,878  25,356  26,133  27,321  ...   52,460   54,297   56,051   57,863
# 2  21,207  21,997  23,425  25,670  ...   55,825   59,663   63,905   64,701
# 3     NaN     NaN     NaN     NaN  ...      NaN      NaN      NaN      NaN
# 4   6,447   6,504   6,419   7,026  ...   14,211   14,938   15,831   15,973
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 54 entries, 0 to 53
# Data columns (total 40 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  51 non-null     object
#  1   1975        35 non-null     object
#  2   1980        35 non-null     object
#  3   1985        35 non-null     object
#  4   1990        35 non-null     object
#  5   1991        35 non-null     object
#  6   1992        35 non-null     object
#  7   1993        35 non-null     object
#  8   1994        35 non-null     object
#  9   1995        35 non-null     object
#  10  1996        35 non-null     object
#  11  1997        35 non-null     object
#  12  1998        35 non-null     object
#  13  1999        35 non-null     object
#  14  2000        35 non-null     object
#  15  2001        35 non-null     object
#  16  2002        35 non-null     object
#  17  2003        35 non-null     object
#  18  2004        35 non-null     object
# ...

# %%
df.dropna(inplace=True) # Modify the original DataFrame directly instead of creating a new one.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 35 entries, 0 to 35
# Data columns (total 40 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  35 non-null     object
#  1   1975        35 non-null     object
#  2   1980        35 non-null     object
#  3   1985        35 non-null     object
#  4   1990        35 non-null     object
#  5   1991        35 non-null     object
#  6   1992        35 non-null     object
#  7   1993        35 non-null     object
#  8   1994        35 non-null     object
#  9   1995        35 non-null     object
#  10  1996        35 non-null     object
#  11  1997        35 non-null     object
#  12  1998        35 non-null     object
#  13  1999        35 non-null     object
#  14  2000        35 non-null     object
#  15  2001        35 non-null     object
#  16  2002        35 non-null     object
#  17  2003        35 non-null     object
#  18  2004        35 non-null     object
# ...

# %%
# delete some columns
df.drop(df.columns[1:20], axis=1, inplace=True)
df.head()
# Out:
#                   Unnamed: 0    2006    2007    2008    2009    2010    2011  \
# 0  TOTAL arriving passengers  78,150  81,068  80,998  76,290  80,817  83,865
# 1     United States carriers  42,946  45,187  45,533  42,460  45,219  46,339
# 2           Foreign carriers  35,204  35,881  35,465  33,830  35,598  37,526
# 4                     Canada  10,846  11,037  11,033  10,263  11,098  11,603
# 5                     Mexico   9,646   9,921   9,847   8,538   9,076   9,190
#
#      2012    2013    2014  ...     2016     2017     2018     2019    2020  \
# 0  87,439  91,787  96,415  ...  108,285  113,959  119,957  122,563  32,261
# 1  47,285  48,719  50,183  ...   52,460   54,297   56,051   57,863  17,607
# 2  40,154  43,068  46,232  ...   55,825   59,663   63,905   64,701  14,654
# 4  12,103  12,780  13,412  ...   14,211   14,938   15,831   15,973   3,458
# 5   9,592  10,414  11,106  ...   13,818   14,849   15,339   15,397   7,064
#
#      2021    2022 (R) 2023 (R) 2024     2025
# ...

# %%
df.columns.values[0] = 'Country'

# %%
df.columns.unique()
# Out:
# Index(['Country', '2006', '2007', '2008', '2009', '2010', '2011', '2012',
#        '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021',
#        '2022', '(R) 2023', '(R) 2024', '2025'],
#       dtype='object')

# %%
df.head()
# Out:
#                      Country    2006    2007    2008    2009    2010    2011  \
# 0  TOTAL arriving passengers  78,150  81,068  80,998  76,290  80,817  83,865
# 1     United States carriers  42,946  45,187  45,533  42,460  45,219  46,339
# 2           Foreign carriers  35,204  35,881  35,465  33,830  35,598  37,526
# 4                     Canada  10,846  11,037  11,033  10,263  11,098  11,603
# 5                     Mexico   9,646   9,921   9,847   8,538   9,076   9,190
#
#      2012    2013    2014  ...     2016     2017     2018     2019    2020  \
# 0  87,439  91,787  96,415  ...  108,285  113,959  119,957  122,563  32,261
# 1  47,285  48,719  50,183  ...   52,460   54,297   56,051   57,863  17,607
# 2  40,154  43,068  46,232  ...   55,825   59,663   63,905   64,701  14,654
# 4  12,103  12,780  13,412  ...   14,211   14,938   15,831   15,973   3,458
# 5   9,592  10,414  11,106  ...   13,818   14,849   15,339   15,397   7,064
#
#      2021    2022 (R) 2023 (R) 2024     2025
# ...

# %%
print(df.columns)
# Out:
# Index(['Country', '2006', '2007', '2008', '2009', '2010', '2011', '2012',
#        '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021',
#        '2022', '(R) 2023', '(R) 2024', '2025'],
#       dtype='object')

# %%
plt.ylabel('Canada')
plt.xlabel('1997')
plt.show()
